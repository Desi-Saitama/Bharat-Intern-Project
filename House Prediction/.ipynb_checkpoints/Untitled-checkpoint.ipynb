# %%
import os
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline

# %%
df = pd.read_csv("./Data/House Price India.csv")

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
count0 = 0
count1 = 0
for _ in df['waterfront present']:
    if _ == 0:
        count0 = count0 + 1
    elif _ == 1:
        count1 = count1 + 1

print("0 = ", count0)
print("1 = ", count1)
# Out:
# 0 =  14508
# 1 =  112

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(df, test_size = 0.2, random_state=42)

# %%
housing = train_set.copy()

# %%
housing.plot(kind = "scatter", x="Longitude", y="Lattitude");

# %%
housing.plot(kind="scatter", x="Longitude", y="Lattitude", alpha=0.4, 
             figsize=(10,7))
plt.show();

# %%
corr_matrix = housing.corr()

# %%
corr_matrix["Price"].sort_values(ascending=False)
# Out:
# Price                                    1.000000
# living area                              0.709182
# grade of the house                       0.665585
# Area of the house(excluding basement)    0.613638
# living_area_renov                        0.584154
# number of bathrooms                      0.528134
# number of views                          0.386296
# Area of the basement                     0.326413
# number of bedrooms                       0.317985
# Lattitude                                0.298915
# number of floors                         0.262771
# waterfront present                       0.257535
# Renovation Year                          0.142044
# lot area                                 0.077200
# lot_area_renov                           0.074468
# Built Year                               0.047574
# condition of the house                   0.043030
# Longitude                                0.020976
# Number of schools nearby                 0.007218
# ...

# %%
def drop_columns(X):
    droped = ['id', 'Postal Code', 'Distance from the airport', 'Number of schools nearby', 'lot_area_renov', 'Built Year']
    return X.drop(droped, axis =1)

# %%
from pandas.plotting import scatter_matrix

attributes = ["number of bedrooms", "living area", "Area of the house(excluding basement)", "Price"]

scatter_matrix(housing[attributes], figsize=(12,8));

# %%
housing = drop_columns(housing)

# %%
X_label = housing['Price']
X = housing.drop(['Price'], axis = 1)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

feed_data = Pipeline([
    ('std_scaler', StandardScaler()),
    ])

# %%
housing_tr = feed_data.fit_transform(X)

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(housing_tr, X_label)
# Out:
# LinearRegression()

# %%
some_data = X.iloc[:5]
some_labels = X_label.iloc[:5]
some_data_prepared = feed_data.transform(some_data)

# %%
print('Predictions:', lin_reg.predict(some_data_prepared))
# Out:
# Predictions: [562446.740713   192694.01373559 260689.95344473 306690.04780461
#  481527.32380796]

# %%
print("Labels: ", list(some_labels))
# Out:
# Labels:  [650000, 309600, 275000, 267800, 305000]

# %%
from sklearn.metrics import mean_squared_error

housing_prediction = lin_reg.predict(housing_tr)
lin_mse = mean_squared_error(X_label, housing_prediction)
lin_mse = np.sqrt(lin_mse)
lin_mse
# Out:
# 206350.40652144805

# %%
from sklearn.metrics import mean_absolute_error as mae

lin_mae = mae(X_label, housing_prediction)
lin_mae
# Out:
# 128267.8431179905

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(lin_reg, X, X_label,
                         scoring="neg_mean_squared_error", cv=10)
lin_rmse_scores = np.sqrt(-scores)

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

display_scores(lin_rmse_scores)
# Out:
# Scores: [204883.05967674 182843.67936132 209941.43480808 201846.02744575
#  188749.77143617 180604.53298339 293644.02002549 194223.72986282
#  197858.0483113  199874.03542978]
# Mean: 205446.833934084
# Standard deviation: 30714.27509295246

# %%
test_set = drop_columns(test_set)

# %%
y_label = test_set['Price']
y = test_set.drop(['Price'], axis = 1)

# %%
y_te = feed_data.transform(y)
